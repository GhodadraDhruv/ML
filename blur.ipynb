# %%
#box blur

import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('tree.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
blur = cv2.blur(img,(6,6))
plt.subplot(1,2,1)
plt.imshow(img)
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(blur)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
#Gaussian Blur

import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('tree.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gaussian = cv2.GaussianBlur(img,(3,3),1)

plt.imshow(gaussian)
plt.title("Gaussian Blur Image")
plt.axis('off')
plt.savefig("tree_blur.jpg")

# %%
#Median Blur

import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('tree.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
median = cv2.medianBlur(img,5)

plt.imshow(median)
plt.title("Median blur image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
#Motion Blur

import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('tree.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
size = 10

# i) Horizontal

k1 = np.zeros((size,size))
k1[size//2,:] = np.ones(size)
k1 = k1/size

horizontal = cv2.filter2D(img,-1,k1)

plt.subplot(1,2,1),plt.title("Horizontal Blur"),plt.imshow(horizontal)
plt.axis('off')


#ii) vertical

k2 = np.zeros((size,size))
k2[:,size//2] = np.ones(size)
k2 = k2 / size

vertical = cv2.filter2D(img,-1,k2)

plt.subplot(1,2,2),plt.title("Vertical Blur"),plt.imshow(vertical)

plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
#grayScaleImgae

import cv2
import matplotlib.pyplot as plt

img = cv2.imread('tree.jpg')

plt.subplot(1,3,1)
plt.imshow(img)
plt.title("BGR image")
plt.axis('off')

rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,2)
plt.imshow(rgb_img)
plt.title("RGB image")
plt.axis('off')

gray_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.subplot(1,3,3)
plt.imshow(gray_image)
plt.title("GRAY image")
plt.axis('off')

print(t
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))
