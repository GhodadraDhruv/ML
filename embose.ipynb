# %%
import cv2
import matplotlib.pyplot as plt  
import numpy as np

img=cv2.imread('paragraph.png',cv2.IMREAD_GRAYSCALE)
# img=cv2.imread('lion.jpg',cv2.IMREAD_GRAYSCALE)

k1=np.array([
    [-2,-1,0],
    [-1,1,1],
    [0,1,2]])

img1=cv2.filter2D(img,-1,k1)



# diff_mask = np.any(img != img1,axis=-1)

# changed_records = np.column_stack(np.where(diff_mask))

# for y,x in changed_records:
#     old_val = img[y,x]
#     new_val = img1[y,x]
#     print(f"Changed Pixel at (x={x},y={y}):{old_val}->{new_val}")

plt.imshow(img1,cmap="gray"),plt.axis('off')
plt.savefig("lion_embose.jpg")
